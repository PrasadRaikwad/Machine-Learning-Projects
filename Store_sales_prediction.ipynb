# %% [markdown]
# # Regression – Prediction of Store Sales

# %% [markdown]
# ### Problem Statement:
# As the success of the retail store depends upon its sales. More the sales made more is the revenue.
#
# The supermarket has several outlets we need to predict the sales which they can expect.
#
# ### Application of predicting the sales:
# We can tell the company what are all the challenges they may face.
#
# What are the brands or products which is sold the most.
#
# This helps sales team to understand which product to sell & which product to promote.
#
# ### Business Objective
# Build a model to predict the Sales of a store

# %% [markdown]
# ### Data Dictionary
# ![DD%201.png](attachment:DD%201.png)

# %% [markdown]
# ## Import Modules

# %%
# importing libraries
import numpy as np                                               # for numerical operations
import pandas as pd                                              # to craete data structures
import matplotlib.pyplot as plt                                  # for visualisation
import seaborn as sns                                            # for visualisation                              
from sklearn import preprocessing                                # for preprocessing the data
from sklearn.preprocessing import MinMaxScaler                   # for scaling the data to make in one range
from sklearn.model_selection import train_test_split             # for splitting the data into train and test set
from sklearn.tree import DecisionTreeRegressor                   # for model building
from sklearn.linear_model import LinearRegression                # for model building
from sklearn.ensemble import RandomForestRegressor               # for model building
from sklearn.ensemble import AdaBoostRegressor                   # for model building
from sklearn.neighbors import KNeighborsRegressor                # for model building
from sklearn.svm import SVR                                      # for model building
from sklearn.ensemble import StackingRegressor                   # for model building
from sklearn.metrics import mean_squared_error                   # for evaluating the model
import warnings                                                  # to remove warnings
warnings.simplefilter(action='ignore')                    
from sklearn.model_selection import KFold                        # for cross validation 
from sklearn.model_selection import cross_val_score              # for evaluation of model
from sklearn.model_selection import cross_val_predict            # for predicting values
import sklearn                                                   # for checking scroing keywords
from numpy import mean                                           # for finding mean values

# %% [markdown]
# ## Loading the dataset

# %%
# Loading data file
df = pd.read_csv('DS3_C6_S1_Regression_StoreSales_Data_Project.csv')

# preview the data file
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.074402
# 4           NCD19         8.93          Low Fat         0.064299
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      Medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# ## Preprocessing the dataset

# %%
# structure of data
print('Shape of data is',df.shape)
# Out:
# Shape of data is (14204, 12)

# %%
# summary of dataset
print('Statistical description of dataset are as follows :')
df.describe()
# Out:
# Statistical description of dataset are as follows :
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  14204.000000     14204.000000  14204.000000               14204.000000
# mean      12.793380         0.070301    141.004977                1997.830681
# std        4.651716         0.048621     62.086938                   8.371664
# min        4.555000         0.003575     31.290000                1985.000000
# 25%        8.710000         0.033143     94.012000                1987.000000
# 50%       12.600000         0.062347    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       21.350000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# for finding null values count
print('Count of null values of all the features is as follows :')
df.isnull().sum()
# Out:
# Count of null values of all the features is as follows :
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
# datatype of attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                14204 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
# check unique values in dataset
df.apply(lambda x: len(x.unique()))
# Out:
# Item_Identifier               1559
# Item_Weight                    415
# Item_Fat_Content                 2
# Item_Visibility              13010
# Item_Type                       16
# Item_MRP                      8052
# Outlet_Identifier               10
# Outlet_Establishment_Year        9
# Outlet_Size                      3
# Outlet_Location_Type             3
# Outlet_Type                      4
# Item_Outlet_Sales             3494
# dtype: int64

# %%
# check for categorical attributes
cat_col = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'object':
        cat_col.append(x)

# removing large unique element values attributes 
cat_col.remove('Item_Identifier')
cat_col.remove('Outlet_Identifier')
cat_col

# print the categorical columns with unique element value counts
for col in cat_col:
    print(col)
    print(df[col].value_counts())
    print('-'*40)
# Out:
# Item_Fat_Content
# Low Fat    9185
# Regular    5019
# Name: Item_Fat_Content, dtype: int64
# ----------------------------------------
# Item_Type
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64
# ----------------------------------------
# Outlet_Size
# Small     7071
# Medium    5580
# High      1553
# Name: Outlet_Size, dtype: int64
# ----------------------------------------
# Outlet_Location_Type
# Tier 3    5583
# Tier 2    4641
# Tier 1    3980
# Name: Outlet_Location_Type, dtype: int64
# ----------------------------------------
# Outlet_Type
# Supermarket Type1    9294
# Grocery Store        1805
# Supermarket Type3    1559
# Supermarket Type2    1546
# Name: Outlet_Type, dtype: int64
# ----------------------------------------

# %% [markdown]
# ### Creating new features

# %%
# creatiing new column to store item type
df['New_Item_Type'] = df['Item_Identifier'].apply(lambda x: x[:2])
df['New_Item_Type']
# Out:
# 0        FD
# 1        DR
# 2        FD
# 3        FD
# 4        NC
#          ..
# 14199    FD
# 14200    FD
# 14201    NC
# 14202    FD
# 14203    FD
# Name: New_Item_Type, Length: 14204, dtype: object

# %%
# replacing names of the item type
df['New_Item_Type'] = df['New_Item_Type'].replace({'FD':'Food', 'NC':'Non-Consumable', 'DR':'Drinks'})
df['New_Item_Type'].value_counts()
# Out:
# Food              10201
# Non-Consumable     2686
# Drinks             1317
# Name: New_Item_Type, dtype: int64

# %%
# creating new element in item fat content as non edible 
df.loc[df['New_Item_Type']=='Non-Consumable', 'Item_Fat_Content'] = 'Non-Edible'
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       6499
# Regular       5019
# Non-Edible    2686
# Name: Item_Fat_Content, dtype: int64

# %%
# creatiing new column to store outelet number
df['New_Outlet_Identifier'] = df['Outlet_Identifier'].apply(lambda x: x[-2:])
df['New_Outlet_Identifier'].value_counts()
# Out:
# 27    1559
# 13    1553
# 49    1550
# 46    1550
# 35    1550
# 45    1548
# 18    1546
# 17    1543
# 10     925
# 19     880
# Name: New_Outlet_Identifier, dtype: int64

# %%
# dropping unecessary columns
df.drop(['Item_Identifier', 'Outlet_Identifier'], axis = 1, inplace = True)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# creating list of numeric datatype columns
num=[]
for i in df.select_dtypes('float64').columns:
    num.append(i)
num
# Out:
# ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales']

# %%
# visualizing distribution of data of all numerical features 
fig,ax = plt.subplots(figsize=(17,15))
c=1
for i in num:
    plt.subplot(2,2,c)
    sns.distplot(df[i],color='teal')
    plt.title(i,fontsize=18)
    plt.xlabel(i,fontsize=15)
    plt.ylabel('Density',fontsize=15)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    c+=1

# %% [markdown]
# #### CONCLUSION :
# 1. Item weight have almost uniform distribution in data. Most of items fall in 7 to 9 category
# 2. Item visibility and item outlet sales have the right skewness in the data
# 3. item MRP can be divided into 4 categories according to price of an item such as cheap, moderate, expensive, very expensive

# %%
# creating list of object datatype columns
obj=[]
for i in df.select_dtypes('object').columns:
    obj.append(i)

# removing item type cause it contents more number of elements to visualize
obj.remove('Item_Type')

# %%
# visualizing count of data of all categorical features 
fig,ax = plt.subplots(figsize=(17,20))
c=1
for i in obj:
    plt.subplot(3,2,c)
    sns.countplot(df[i], order = df[i].value_counts().index, palette='Set3', edgecolor='k')
    plt.title(i,fontsize=18)
    plt.xlabel(i,fontsize=15)
    plt.ylabel('Count',fontsize=15)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    c+=1

# %%
# visualizing count of data of all categorical features 
plt.figure(figsize=(10,8))
sns.countplot(y=df['Item_Type'], order = df['Item_Type'].value_counts().index)
plt.title('Item_Type',fontsize=18)
plt.xlabel('Item_Type',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);

# %%
# removing item type cause it contents more number of elements to visualize
obj.remove('New_Outlet_Identifier')

# visualizing count of data of all categorical features 
fig,ax = plt.subplots(figsize=(17,10))

def label_function(val):
    return f'{val / 100 * len(df):.0f}\n{val:.0f}%'
c=1
for i in obj:
    plt.subplot(2,3,c)
    df.groupby(df[i]).size().plot(kind='pie',autopct=label_function, textprops={'fontsize': 14},cmap='Set3',
                                  wedgeprops={"edgecolor":"black",'linewidth': 1, 'linestyle': 'solid'})
    plt.title(i,fontsize=18)
    plt.ylabel('')
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    c+=1

# %% [markdown]
# #### CONCLUSION :
# 1. Most items sold are from food category which is around 72% and Least items sold are from drinks category which is only 9%.
# 2. In food category Fruits and vegetables are sold most and seafoods are sold very least.
# 3. Most sold products have low fat content which is around 46% of total items and least items are non edible which is around 19% only.
# 4. Most of the outlets are small in size i.e. around 50% of total outlets and least are high in size i.e. around 11% only.
# 5. All Outlets are almost equally distributed according to location.
# 6. Supermarket Type 1 outlets are most which is around 65% of total outlets.

# %% [markdown]
# ### Label Encoding

# %%
# creating list of object datatype columns
obj=[]
for i in df.select_dtypes('object').columns:
    obj.append(i)

# converting non-numeric columns into categorical datatype column
for i in obj:
      df[i]=df[i].astype('category')
        
# checking datatypes of all columns after coverting datatype into categorical columns
print('Datatype of all columns in dataset:')
df.info()
# Out:
# Datatype of all columns in dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                14204 non-null  float64
#  1   Item_Fat_Content           14204 non-null  category
#  2   Item_Visibility            14204 non-null  float64
#  3   Item_Type                  14204 non-null  category
#  4   Item_MRP                   14204 non-null  float64
#  5   Outlet_Establishment_Year  14204 non-null  int64
#  6   Outlet_Size                14204 non-null  category
#  7   Outlet_Location_Type       14204 non-null  category
#  8   Outlet_Type                14204 non-null  category
#  9   Item_Outlet_Sales          8523 non-null   float64
#  10  New_Item_Type              14204 non-null  category
#  11  New_Outlet_Identifier      14204 non-null  category
# dtypes: category(7), float64(4), int64(1)
# memory usage: 653.8 KB

# %%
# creating list of categorical datatype columns 
category=[]
for i in df.select_dtypes('category').columns:
      category.append(i)

# label encoder technique to convert categorical column to numerical type
for i in category:
      df[i+str('_encode')] = preprocessing.LabelEncoder().fit_transform(df[i])
df.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.074402  Fruits and Vegetables
# 4         8.93       Non-Edible         0.064299              Household
#
#    Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0  249.8092                       1999      Medium               Tier 1
# 1   48.2692                       2009      Medium               Tier 3
# 2  141.6180                       1999      Medium               Tier 1
# 3  182.0950                       1998      Medium               Tier 3
# 4   53.8614                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales   New_Item_Type New_Outlet_Identifier  \
# 0  Supermarket Type1          3735.1380            Food                    49
# 1  Supermarket Type2           443.4228          Drinks                    18
# 2  Supermarket Type1          2097.2700            Food                    49
# 3      Grocery Store           732.3800            Food                    10
# 4  Supermarket Type1           994.7052  Non-Consumable                    13
#
#    Item_Fat_Content_encode  Item_Type_encode  Outlet_Size_encode  \
# 0                        0                 4                   1
# 1                        2                14                   1
# 2                        0                10                   1
# 3                        2                 6                   1
# 4                        1                 9                   0
#
#    Outlet_Location_Type_encode  Outlet_Type_encode  New_Item_Type_encode  \
# 0                            0                   1                     1
# 1                            2                   2                     0
# 2                            0                   1                     1
# 3                            2                   0                     1
# 4                            2                   1                     2
#
#    New_Outlet_Identifier_encode
# 0                             9
# 1                             3
# 2                             9
# 3                             0
# 4                             1

# %%
# printing which label is assigned to which number 
for i in category:
    print(pd.DataFrame({str(i):df[i].unique(), i+str('_encode'):df[i+str('_encode')].unique()})
          .sort_values(i+str('_encode')))
    print('-'*50)
# Out:
#   Item_Fat_Content  Item_Fat_Content_encode
# 0          Low Fat                        0
# 2       Non-Edible                        1
# 1          Regular                        2
# --------------------------------------------------
#                 Item_Type  Item_Type_encode
# 5            Baking Goods                 0
# 12                 Breads                 1
# 8               Breakfast                 2
# 11                 Canned                 3
# 0                   Dairy                 4
# 7            Frozen Foods                 5
# 3   Fruits and Vegetables                 6
# 10            Hard Drinks                 7
# 9      Health and Hygiene                 8
# 4               Household                 9
# 2                    Meat                10
# 14                 Others                11
# 15                Seafood                12
# 6             Snack Foods                13
# 1             Soft Drinks                14
# 13          Starchy Foods                15
# --------------------------------------------------
#   Outlet_Size  Outlet_Size_encode
# 1        High                   0
# 0      Medium                   1
# 2       Small                   2
# --------------------------------------------------
#   Outlet_Location_Type  Outlet_Location_Type_encode
# 0               Tier 1                            0
# 2               Tier 2                            1
# 1               Tier 3                            2
# --------------------------------------------------
#          Outlet_Type  Outlet_Type_encode
# 2      Grocery Store                   0
# 0  Supermarket Type1                   1
# 1  Supermarket Type2                   2
# 3  Supermarket Type3                   3
# --------------------------------------------------
#     New_Item_Type  New_Item_Type_encode
# 1          Drinks                     0
# 0            Food                     1
# 2  Non-Consumable                     2
# --------------------------------------------------
#   New_Outlet_Identifier  New_Outlet_Identifier_encode
# 2                    10                             0
# 3                    13                             1
# 6                    17                             2
# 1                    18                             3
# 9                    19                             4
# 4                    27                             5
# 8                    35                             6
# 5                    45                             7
# 7                    46                             8
# 0                    49                             9
# --------------------------------------------------

# %% [markdown]
# ### Feature Scaling

# %%
# feature scaling using minmax scaler
numerics = ['int64','float64','int32']   # datatype
df1 = df.select_dtypes(include=numerics)  
df_scaled=pd.DataFrame(MinMaxScaler().fit_transform(df1.to_numpy()),columns=df1.columns)  # using minmax scaler
print('Dataframe with minmax scaler values is as follows :')
df_scaled.head()   # preview of dataframe after scaling
# Out:
# Dataframe with minmax scaler values is as follows :
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0     0.282525         0.038399  0.927507                   0.583333
# 1     0.081274         0.048346  0.072068                   1.000000
# 2     0.770765         0.040593  0.468288                   0.583333
# 3     0.871986         0.218055  0.640093                   0.541667
# 4     0.260494         0.186950  0.095805                   0.083333
#
#    Item_Outlet_Sales  Item_Fat_Content_encode  Item_Type_encode  \
# 0           0.283587                      0.0          0.266667
# 1           0.031419                      1.0          0.933333
# 2           0.158115                      0.0          0.666667
# 3           0.053555                      1.0          0.400000
# 4           0.073651                      0.5          0.600000
#
#    Outlet_Size_encode  Outlet_Location_Type_encode  Outlet_Type_encode  \
# 0                 0.5                          0.0            0.333333
# 1                 0.5                          1.0            0.666667
# 2                 0.5                          0.0            0.333333
# 3                 0.5                          1.0            0.000000
# 4                 0.0                          1.0            0.333333
#
#    New_Item_Type_encode  New_Outlet_Identifier_encode
# 0                   0.5                      1.000000
# 1                   0.0                      0.333333
# 2                   0.5                      1.000000
# 3                   0.5                      0.000000
# 4                   1.0                      0.111111

# %% [markdown]
# ### Feature Selection

# %%
# correlation among numerical features
df_scaled.corr().style.background_gradient(cmap='PuRd')
# Out:
# <style type="text/css">
# #T_5f3b5_row0_col0, #T_5f3b5_row1_col1, #T_5f3b5_row2_col2, #T_5f3b5_row3_col3, #T_5f3b5_row4_col4, #T_5f3b5_row5_col5, #T_5f3b5_row6_col6, #T_5f3b5_row7_col7, #T_5f3b5_row8_col8, #T_5f3b5_row9_col9, #T_5f3b5_row10_col10, #T_5f3b5_row11_col11 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_5f3b5_row0_col1, #T_5f3b5_row0_col4, #T_5f3b5_row5_col4, #T_5f3b5_row8_col1, #T_5f3b5_row10_col4 {
#   background-color: #e6e0ee;
#   color: #000000;
# }
# #T_5f3b5_row0_col2 {
#   background-color: #f1edf6;
#   color: #000000;
# }
# #T_5f3b5_row0_col3, #T_5f3b5_row2_col3, #T_5f3b5_row5_col3, #T_5f3b5_row10_col3 {
#   background-color: #e9e4f1;
#   color: #000000;
# }
# #T_5f3b5_row0_col5 {
#   background-color: #efebf4;
#   color: #000000;
# }
# #T_5f3b5_row0_col6, #T_5f3b5_row10_col1 {
#   background-color: #eae5f1;
#   color: #000000;
# }
# #T_5f3b5_row0_col7, #T_5f3b5_row10_col7 {
#   background-color: #c995c7;
#   color: #f1f1f1;
# }
# #T_5f3b5_row0_col8, #T_5f3b5_row2_col8, #T_5f3b5_row2_col11, #T_5f3b5_row5_col8, #T_5f3b5_row5_col11, #T_5f3b5_row6_col11, #T_5f3b5_row10_col8, #T_5f3b5_row10_col11 {
#   background-color: #d085c0;
#   color: #f1f1f1;
# }
# #T_5f3b5_row0_col9, #T_5f3b5_row6_col9, #T_5f3b5_row9_col7 {
#   background-color: #dac6e1;
#   color: #000000;
# }
# #T_5f3b5_row0_col10 {
#   background-color: #e8e2f0;
#   color: #000000;
# }
# #T_5f3b5_row0_col11, #T_5f3b5_row6_col8 {
#   background-color: #d183bf;
#   color: #f1f1f1;
# }
# #T_5f3b5_row1_col0, #T_5f3b5_row1_col2, #T_5f3b5_row1_col4, #T_5f3b5_row1_col10, #T_5f3b5_row5_col6, #T_5f3b5_row6_col5, #T_5f3b5_row7_col9, #T_5f3b5_row8_col7, #T_5f3b5_row8_col11, #T_5f3b5_row9_col1, #T_5f3b5_row9_col3, #T_5f3b5_row11_col8 {
#   background-color: #f7f4f9;
#   color: #000000;
# }
# #T_5f3b5_row1_col3, #T_5f3b5_row8_col3 {
#   background-color: #f3f0f7;
#   color: #000000;
# }
# #T_5f3b5_row1_col5, #T_5f3b5_row4_col5, #T_5f3b5_row4_col6, #T_5f3b5_row10_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_5f3b5_row1_col6, #T_5f3b5_row4_col0, #T_5f3b5_row4_col1 {
#   background-color: #f3eff6;
#   color: #000000;
# }
# #T_5f3b5_row1_col7 {
#   background-color: #cb8fc5;
#   color: #f1f1f1;
# }
# #T_5f3b5_row1_col8 {
#   background-color: #ce89c2;
#   color: #f1f1f1;
# }
# #T_5f3b5_row1_col9, #T_5f3b5_row2_col5, #T_5f3b5_row3_col1, #T_5f3b5_row3_col5, #T_5f3b5_row7_col5, #T_5f3b5_row7_col6, #T_5f3b5_row9_col5, #T_5f3b5_row11_col5 {
#   background-color: #eeeaf4;
#   color: #000000;
# }
# #T_5f3b5_row1_col11 {
#   background-color: #cb9bca;
#   color: #f1f1f1;
# }
# #T_5f3b5_row2_col0, #T_5f3b5_row6_col0, #T_5f3b5_row6_col2, #T_5f3b5_row7_col10, #T_5f3b5_row11_col1, #T_5f3b5_row11_col10 {
#   background-color: #f0ecf5;
#   color: #000000;
# }
# #T_5f3b5_row2_col1 {
#   background-color: #e5dded;
#   color: #000000;
# }
# #T_5f3b5_row2_col4 {
#   background-color: #e72c8c;
#   color: #f1f1f1;
# }
# #T_5f3b5_row2_col6, #T_5f3b5_row3_col9, #T_5f3b5_row6_col3 {
#   background-color: #e9e3f0;
#   color: #000000;
# }
# #T_5f3b5_row2_col7, #T_5f3b5_row5_col7, #T_5f3b5_row6_col7 {
#   background-color: #ca96c8;
#   color: #f1f1f1;
# }
# #T_5f3b5_row2_col9, #T_5f3b5_row5_col9, #T_5f3b5_row10_col9 {
#   background-color: #dbc8e2;
#   color: #000000;
# }
# #T_5f3b5_row2_col10, #T_5f3b5_row10_col6 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_5f3b5_row3_col0, #T_5f3b5_row7_col0, #T_5f3b5_row9_col0, #T_5f3b5_row11_col0 {
#   background-color: #f4f1f7;
#   color: #000000;
# }
# #T_5f3b5_row3_col2, #T_5f3b5_row5_col0, #T_5f3b5_row5_col2, #T_5f3b5_row8_col2, #T_5f3b5_row9_col2, #T_5f3b5_row11_col2 {
#   background-color: #f6f3f8;
#   color: #000000;
# }
# #T_5f3b5_row3_col4 {
#   background-color: #ede9f3;
#   color: #000000;
# }
# #T_5f3b5_row3_col6, #T_5f3b5_row7_col8, #T_5f3b5_row8_col5, #T_5f3b5_row8_col6, #T_5f3b5_row9_col6, #T_5f3b5_row11_col6 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_5f3b5_row3_col7 {
#   background-color: #e32682;
#   color: #f1f1f1;
# }
# #T_5f3b5_row3_col8 {
#   background-color: #ca97c9;
#   color: #f1f1f1;
# }
# #T_5f3b5_row3_col10, #T_5f3b5_row8_col10, #T_5f3b5_row9_col10 {
#   background-color: #f1edf5;
#   color: #000000;
# }
# #T_5f3b5_row3_col11 {
#   background-color: #d873b7;
#   color: #f1f1f1;
# }
# #T_5f3b5_row4_col2 {
#   background-color: #e4429a;
#   color: #f1f1f1;
# }
# #T_5f3b5_row4_col3, #T_5f3b5_row4_col10, #T_5f3b5_row6_col10, #T_5f3b5_row7_col4 {
#   background-color: #efeaf4;
#   color: #000000;
# }
# #T_5f3b5_row4_col7 {
#   background-color: #cda0cd;
#   color: #000000;
# }
# #T_5f3b5_row4_col8 {
#   background-color: #da70b5;
#   color: #f1f1f1;
# }
# #T_5f3b5_row4_col9 {
#   background-color: #e159a8;
#   color: #f1f1f1;
# }
# #T_5f3b5_row4_col11 {
#   background-color: #e05eac;
#   color: #f1f1f1;
# }
# #T_5f3b5_row5_col1 {
#   background-color: #e2d6e9;
#   color: #000000;
# }
# #T_5f3b5_row5_col10 {
#   background-color: #d7c0de;
#   color: #000000;
# }
# #T_5f3b5_row6_col1 {
#   background-color: #e8e3f0;
#   color: #000000;
# }
# #T_5f3b5_row6_col4 {
#   background-color: #e6deee;
#   color: #000000;
# }
# #T_5f3b5_row7_col1 {
#   background-color: #e0d3e8;
#   color: #000000;
# }
# #T_5f3b5_row7_col2 {
#   background-color: #f6f3f9;
#   color: #000000;
# }
# #T_5f3b5_row7_col3 {
#   background-color: #dd69b2;
#   color: #f1f1f1;
# }
# #T_5f3b5_row7_col11 {
#   background-color: #df2179;
#   color: #f1f1f1;
# }
# #T_5f3b5_row8_col0 {
#   background-color: #f5f2f8;
#   color: #000000;
# }
# #T_5f3b5_row8_col4 {
#   background-color: #dccae3;
#   color: #000000;
# }
# #T_5f3b5_row8_col9 {
#   background-color: #e44099;
#   color: #f1f1f1;
# }
# #T_5f3b5_row9_col4, #T_5f3b5_row9_col11 {
#   background-color: #db6fb5;
#   color: #f1f1f1;
# }
# #T_5f3b5_row9_col8 {
#   background-color: #da1d6f;
#   color: #f1f1f1;
# }
# #T_5f3b5_row10_col2 {
#   background-color: #f2eff6;
#   color: #000000;
# }
# #T_5f3b5_row10_col5 {
#   background-color: #d5bbdb;
#   color: #000000;
# }
# #T_5f3b5_row11_col3 {
#   background-color: #dfd1e6;
#   color: #000000;
# }
# #T_5f3b5_row11_col4 {
#   background-color: #d3b5d8;
#   color: #000000;
# }
# #T_5f3b5_row11_col7 {
#   background-color: #e42684;
#   color: #f1f1f1;
# }
# #T_5f3b5_row11_col9 {
#   background-color: #d1aed4;
#   color: #000000;
# }
# </style>
# <table id="T_5f3b5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Item_Weight</th>
#       <th class="col_heading level0 col1" >Item_Visibility</th>
#       <th class="col_heading level0 col2" >Item_MRP</th>
#       <th class="col_heading level0 col3" >Outlet_Establishment_Year</th>
#       <th class="col_heading level0 col4" >Item_Outlet_Sales</th>
#       <th class="col_heading level0 col5" >Item_Fat_Content_encode</th>
#       <th class="col_heading level0 col6" >Item_Type_encode</th>
#       <th class="col_heading level0 col7" >Outlet_Size_encode</th>
#       <th class="col_heading level0 col8" >Outlet_Location_Type_encode</th>
#       <th class="col_heading level0 col9" >Outlet_Type_encode</th>
#       <th class="col_heading level0 col10" >New_Item_Type_encode</th>
#       <th class="col_heading level0 col11" >New_Outlet_Identifier_encode</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f3b5_level0_row0" class="row_heading level0 row0" >Item_Weight</th>
#       <td id="T_5f3b5_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5f3b5_row0_col1" class="data row0 col1" >-0.020472</td>
#       <td id="T_5f3b5_row0_col2" class="data row0 col2" >0.035751</td>
#       <td id="T_5f3b5_row0_col3" class="data row0 col3" >0.000247</td>
#       <td id="T_5f3b5_row0_col4" class="data row0 col4" >0.013261</td>
#       <td id="T_5f3b5_row0_col5" class="data row0 col5" >-0.010897</td>
#       <td id="T_5f3b5_row0_col6" class="data row0 col6" >0.031884</td>
#       <td id="T_5f3b5_row0_col7" class="data row0 col7" >0.000944</td>
#       <td id="T_5f3b5_row0_col8" class="data row0 col8" >-0.001719</td>
#       <td id="T_5f3b5_row0_col9" class="data row0 col9" >0.001913</td>
#       <td id="T_5f3b5_row0_col10" class="data row0 col10" >0.068781</td>
#       <td id="T_5f3b5_row0_col11" class="data row0 col11" >0.003002</td>
#     </tr>
#     <tr>
#       <th id="T_5f3b5_level0_row1" class="row_heading level0 row1" >Item_Visibility</th>
#       <td id="T_5f3b5_row1_col0" class="data row1 col0" >-0.020472</td>
#       <td id="T_5f3b5_ro

# %%
# Selecting Features having Correlation greater than 0.05
select = []
for i in df_scaled:
      if abs(df_scaled[i].corr(df_scaled['Item_Outlet_Sales']))>=0.05 :
            select.append(i)

# plotting heatmap among selected features
fig, ax = plt.subplots(figsize=(17,5)) 
ax =(sns.heatmap(df_scaled[select]
             .corr(), annot = True, cmap="PuRd",annot_kws={"size": 13})
.set(title = "Correlation matrix\n"))
plt.show()

# %%
# final dataset for model building
df_final = df_scaled[select]
df_final.head()
# Out:
#    Item_Visibility  Item_MRP  Item_Outlet_Sales  Outlet_Size_encode  \
# 0         0.038399  0.927507           0.283587                 0.5
# 1         0.048346  0.072068           0.031419                 0.5
# 2         0.040593  0.468288           0.158115                 0.5
# 3         0.218055  0.640093           0.053555                 0.5
# 4         0.186950  0.095805           0.073651                 0.0
#
#    Outlet_Location_Type_encode  Outlet_Type_encode  \
# 0                          0.0            0.333333
# 1                          1.0            0.666667
# 2                          0.0            0.333333
# 3                          1.0            0.000000
# 4                          1.0            0.333333
#
#    New_Outlet_Identifier_encode
# 0                      1.000000
# 1                      0.333333
# 2                      1.000000
# 3                      0.000000
# 4                      0.111111

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Spliting Data into input and prediction

# %%
# taking non-null values as input
df_input = df_final[~df_final['Item_Outlet_Sales'].isnull()]
df_input.head()
# Out:
#    Item_Visibility  Item_MRP  Item_Outlet_Sales  Outlet_Size_encode  \
# 0         0.038399  0.927507           0.283587                 0.5
# 1         0.048346  0.072068           0.031419                 0.5
# 2         0.040593  0.468288           0.158115                 0.5
# 3         0.218055  0.640093           0.053555                 0.5
# 4         0.186950  0.095805           0.073651                 0.0
#
#    Outlet_Location_Type_encode  Outlet_Type_encode  \
# 0                          0.0            0.333333
# 1                          1.0            0.666667
# 2                          0.0            0.333333
# 3                          1.0            0.000000
# 4                          1.0            0.333333
#
#    New_Outlet_Identifier_encode
# 0                      1.000000
# 1                      0.333333
# 2                      1.000000
# 3                      0.000000
# 4                      0.111111

# %%
# taking null values as prediction
df_pred = df_final[df_final['Item_Outlet_Sales'].isnull()]
df_pred.head()
# Out:
#       Item_Visibility  Item_MRP  Item_Outlet_Sales  Outlet_Size_encode  \
# 8523         0.012284  0.325012                NaN                 0.5
# 8524         0.107301  0.237819                NaN                 1.0
# 8525         0.295552  0.893316                NaN                 0.5
# 8526         0.036370  0.525233                NaN                 1.0
# 8527         0.354122  0.861381                NaN                 0.5
#
#       Outlet_Location_Type_encode  Outlet_Type_encode  \
# 8523                          0.0            0.333333
# 8524                          0.5            0.333333
# 8525                          1.0            0.000000
# 8526                          0.5            0.333333
# 8527                          1.0            1.000000
#
#       New_Outlet_Identifier_encode
# 8523                      1.000000
# 8524                      0.222222
# 8525                      0.000000
# 8526                      0.222222
# 8527                      0.555556

# %%
print('Size of the input data is',df_input.shape[0],'\nSize of the prediction data is',df_pred.shape[0])
# Out:
# Size of the input data is 8523
# Size of the prediction data is 5681

# %% [markdown]
# #### Using K-Fold cross validation method

# %%
# specifying x and y
X = df_input.loc[:, df_input.columns != 'Item_Outlet_Sales']
Y = df_input['Item_Outlet_Sales']

# creating list
R2_Score, Mean_Squared_Error, Root_Mean_Squared_Error, Mean_Absolute_Error= list(), list(), list(), list()

# creating function to build model and to evaluate it
def MODEL(model, X, Y):
    cv = KFold(n_splits=10, shuffle=False, random_state=None)
    r2 = cross_val_score(model, X, Y, scoring='r2', cv=cv, n_jobs=-1, error_score='raise')
    mse = cross_val_score(model, X, Y, scoring='neg_mean_squared_error', cv=cv, n_jobs=-1, error_score='raise')
    rmse = cross_val_score(model, X, Y, scoring='neg_root_mean_squared_error', cv=cv, n_jobs=-1, error_score='raise')
    mae = cross_val_score(model, X, Y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
    
    R2_Score.append(r2)
    Mean_Squared_Error.append(mse)
    Root_Mean_Squared_Error.append(rmse)
    Mean_Absolute_Error.append(mae)
    
    print('R2-Score: {} %'.format(abs(round((mean(r2)*100),2))))
    print('Mean Squared Error: {} %'.format(abs(round((mean(mse)*100),2))))
    print('Root Mean Squared Error: {} %'.format(abs(round((mean(rmse)*100),2))))
    print('Mean Absolute Error: {} %'.format(abs(round((mean(mae)*100),2))))

# %% [markdown]
# ### Model 1 : Linear Regression Model

# %%
MODEL(LinearRegression(), X, Y)
# Out:
# R2-Score: 50.0 %
# Mean Squared Error: 0.85 %
# Root Mean Squared Error: 9.23 %
# Mean Absolute Error: 6.94 %

# %% [markdown]
# ### Model 2 : Decision Tree Regression Model

# %%
MODEL(DecisionTreeRegressor(), X, Y)
# Out:
# R2-Score: 18.57 %
# Mean Squared Error: 1.38 %
# Root Mean Squared Error: 11.72 %
# Mean Absolute Error: 8.12 %

# %% [markdown]
# ### Model 3 : Random Forest Regression Model

# %%
MODEL(RandomForestRegressor(), X, Y)
# Out:
# R2-Score: 54.04 %
# Mean Squared Error: 0.78 %
# Root Mean Squared Error: 8.82 %
# Mean Absolute Error: 6.15 %

# %% [markdown]
# ### Model 4 : Adaptive boosting Regression Model

# %%
MODEL(AdaBoostRegressor(), X, Y)
# Out:
# R2-Score: 51.39 %
# Mean Squared Error: 0.84 %
# Root Mean Squared Error: 9.25 %
# Mean Absolute Error: 7.21 %

# %% [markdown]
# ### Model 5 : Stacking Regression Model

# %%
# get a stacking ensemble of models
def get_stacking():
    # define the base models
    level0 = list()
    level0.append(('knn', KNeighborsRegressor()))
    level0.append(('cart', DecisionTreeRegressor()))
    level0.append(('svm', SVR()))
    # define meta learner model
    level1 = LinearRegression()
    # define the stacking ensemble
    model = StackingRegressor(estimators=level0, final_estimator=level1, cv=5)
    return model

MODEL(get_stacking(), X, Y)
# Out:
# R2-Score: 59.46 %
# Mean Squared Error: 0.69 %
# Root Mean Squared Error: 8.3 %
# Mean Absolute Error: 5.89 %

# %% [markdown]
# ### Evaluation of models

# %%
# creating list to help in visualization of model evaluation score
names=['Linear Regression','Decision Tree','Random Forest','Adaptive boosting','Stacking']
results = [R2_Score, Mean_Squared_Error, Root_Mean_Squared_Error, Mean_Absolute_Error]
scores=['R2 Score','Mean Squared Error','Root Mean Squared Error','Mean Absolute Error']

# visualizing count of data of all categorical features 
fig,ax = plt.subplots(figsize=(17,18))
c=1
for i in range(len(results)):
    plt.subplot(2,2,c)
    plt.boxplot(results[i], labels=names, showmeans=True)
    plt.xlabel('Models', fontsize = 15)
    plt.ylabel(scores[i], fontsize = 15)
    plt.title(scores[i], fontsize = 18)
    plt.xticks(fontsize = 12, rotation=10)
    plt.yticks(fontsize = 12)
    c+=1

# %% [markdown]
# #### CONCLUSION :
# 1. Among all models 'Stacking Regression Model' gives the best performance. Having Highest R2 score and lowest error scores among all models.
#
#    Stacking Regression Model:
#
#    a. R2-Score: 59.46 %
#
#    b. Mean Squared Error: 0.69 %
#
#    c. Root Mean Squared Error: 8.3 %
#
#    d. Mean Absolute Error: 5.89 %

# %% [markdown]
# #### Using 'Stacking Regression Model' predicting test values from input data of sales

# %% [markdown]
# ##### a. Creating test and training datasets from input data of sales

# %%
# Creating test and training datasets
df_train, df_test = train_test_split(df_input,train_size = 0.8)

X_train = df_train.drop(columns='Item_Outlet_Sales', axis =1)
Y_train = df_train['Item_Outlet_Sales']
X_test = df_test.drop(columns='Item_Outlet_Sales', axis =1)
Y_test = df_test['Item_Outlet_Sales']

print('Size of training dataset from input data is', Y_train.shape[0])
print('Size of test dataset from input data is', Y_test.shape[0])
# Out:
# Size of training dataset from input data is 6818
# Size of test dataset from input data is 1705

# %% [markdown]
# ##### b. Training model

# %%
# training model
MODEL(get_stacking(), X_train, Y_train)
# Out:
# R2-Score: 59.18 %
# Mean Squared Error: 0.69 %
# Root Mean Squared Error: 8.28 %
# Mean Absolute Error: 5.92 %

# %% [markdown]
# ##### c. Predicting values

# %%
# predicting values
cv = KFold(n_splits=10, shuffle=False, random_state=None)
Y_pred = cross_val_predict(get_stacking(), X_test, Y_test, cv=cv)
Y_pred
# Out:
# array([0.07923709, 0.03698946, 0.17883057, ..., 0.19717763, 0.2658333 ,
#        0.05832795])

# %% [markdown]
# ##### d. Plotting actual and predicted values of first 50 datapoints

# %%
# plotting actual and pred values of first 50 datapoints 
x_1 = list(np.arange(0,len(Y_test.iloc[:50])))
plt.figure(figsize=(17,5))
plt.scatter(x_1,Y_test.iloc[:50],color='red')
plt.scatter(x_1,pd.Series(Y_pred).iloc[:50],color='blue')
plt.xlabel('X', fontsize = 15)
plt.ylabel('Sales predicted and Sales actual' , fontsize = 15)
plt.legend(['Actual','Predicted'],loc="upper right",fontsize = 12)
plt.title('Scatter plot of Sales predicted and Sales actual', fontsize = 18);

# %% [markdown]
# #### Using 'Stacking Regression Model' predicting null values from sales

# %%
# setting x value except target value as sales
X_test_pred = df_pred.drop(columns='Item_Outlet_Sales', axis =1)

# training model
model=get_stacking()
model.fit(X_train,Y_train)

# predicting values
print('Prediction of null values from Sales are as follows:')
model.predict(X_test_pred)
# Out:
# Prediction of null values from Sales are as follows:
# array([0.11692993, 0.08706516, 0.04783372, ..., 0.13047164, 0.28163589,
#        0.09221482])
